# %% [markdown]
# # Classses and objects

# %% [markdown]
# ### classs is a  blue preint for creating objects , attributes , methods

# %%
# here "car " is name of the casss 
# audei is an object of class car 

class car :
    pass

audi = car()
bmw =car()

print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)

# %%
# her windows will be an attribute of the car 
# this is not the proper way of intialization of attribute 
audi.windows = 4 # windows is an instnce of audi (which is object of the clas car )
print(audi.windows)
# Out:
# 4

# %%
## instance variable and method[]

tata = car()
tata.doors =4
print(tata.doors)
# here door is an atrtribute
# Out:
# 4

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
# insances varaiables and methods 
class Dog :
    ## constructor ---__init___ this helps to define all or any of the  the attributes whit this init funcutoin
    # with is  "__init__" will be able to definr the any particular attribute 
    # herere in place of ---self---- we can use any thing to acess this 
    #----self.name---- this becomesan instance variable insisedan class
    def __init__(self , name,age) : # here name and age arethe two attributes 
        self.name = name
        self.age = age

## creating an object
dog1 = Dog('buddy', 1)    # as we call the class dog it exce the instructor --so her we are also nned to provide the two prarameter we created in the constructor     
print(dog1)

# we can retrivethis 

print(dog1.name)
print(dog1.age)
# Out:
# ...
# buddy
# 1

# %%
# definng the class with instance mathod (varable are such as name , mehthods are such as dog is barking )

class dog :
    def __init__(self, name , age ) : # we can also callthis as the property of calss dog 
        self.name = name 
        self.age = age 
    

    #  instance method
    def bark (self ) :# inside pf this also we can make use of --name ,age --- keywords
        print(f'{self.name} says woof')


dog1 =dog('BUDDY ' , 3)
dog1.bark()

dog2 = dog("luffy" , 20)
dog2.bark()
# Out:
# BUDDY  says woof
# luffy says woof

# %%
# modelling an bank account

#defin a class for bank account

class BankAccount :
    def __init__(self, owner , balance):
        self.owner = owner 
        self.balance  = balance 


    def deposit(self , amount) :
        self.balance+=amount
        print(f'the totalt amountis {self.balance}')

    def widraw(self,amount):

        if amount > self.balance :
            print('indufficient')
        else :
            self.balance-= amount
            print(f"{self.balance}")   

    def balance (self):
        return self.balance



# creating an new bank acoount 
account1 = BankAccount("luffy" , 3)
print(account1.balance)
# Out:
# 3

# %%
account1.deposit(100)
account1.widraw(50)
# Out:
# the totalt amountis 103
# 53
