# %% [markdown]
# # Inheritance

# %% [markdown]
# aloows aclass to inherithe attributes and methids from another class

# %%
## inheritanc 
# parent class
class car :
    def __init__(self , windows ,doors, enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype 
        # 1= 2 --2 need not needed to be of the same name 

    def drive(self) :
        print(f" this tcar is {self.enginetype}")

# %%
car1 = car(4,6,'petrol')
print(car1.drive())
# Out:
#  this tcar is petrol
# None

# %%
# here the clas tesla will inherit he class car it will inhereit hte property of car in init and also we can add somenew ones
# class child(parent from which we will inherit )
# super( ) --- indicate s we ae trying ti call theinit method or d=getting hte atrributes from the parent class
class tesla(car)  :
    def __init__ (self, windows , doors , enginetypr, isdelfdriving) :
