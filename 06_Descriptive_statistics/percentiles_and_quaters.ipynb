# %% [markdown]
# # Percentile and Quater

# %% [markdown]
# 1. aher to find the percentage of the odd number in given group  = (3/6) x 100   ----- 3 indidcates odd number in grp ---6 is the total number in the grp

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ----# ---- indaicate hte number
# 1. the value undicates that the 78 percent of the entire distribution is lesss than nine

# %% [markdown]
# if weare are ask waht is 25 percentile of this distribution
#
# 2. so we ahve to find the "Value" fofr given "percentage"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. in distribution therris not an value as 3.85 so we will be considering the 3,4  and  taking there average we get the value as " 3.5 "

# %% [markdown]
# # Quartiles

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# every 25 percentile is quartiles ----- > this simply means quarter

# %% [markdown]
# # 5 number summary and box plot
# this is important to find outliers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Removing the outliers
#
# 1. bu loking at  te distribution we can find that ehich is the oulier here it is 29 as it is most tsnading out in the distribuiton

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. ifthereis any element thais below the lower fence then its conisderd as outlier ---> ex : -29 it isa an outlier
# 2. this works sameas the name suggest teh  fences the value that sallls in this fence is an value from distribution f he calue fallls below or above of this fence then it is not part of dist
#
# 2. here "(19 + 1) " is "(N + 1 )"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. once we find the LF and HF then we can find the rnage of the fence

# %% [markdown]
# ### box plot using  5 NUmber summmary

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we sel the element for minimumand maximum by  excludin the outliers from the dist
