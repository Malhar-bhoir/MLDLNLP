# %% [markdown]
# # measureof dispersion
#
# usedtofind out how far the one value in dataset is from other vakue in dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Range
#
# diffbte the maximum value and the minimum value in dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# in here we only consider the maimum value adn the smalller value  we are not considerin the rest of te values i present in the dataset ----> this indicates ----> rough measure of the dispersion

# %% [markdown]
# # variance
# measure the average square deviation of each value from mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---sensetive to te outliers indicste can be identified by add an 100 to the above example and then cal the var the var willl be hiher we do so

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# variance determinsesd the spread of the data
# ![image.png](attachment:image.png)

# %% [markdown]
# here suppose we have tw oelemets then also we are not sure how far both the 8 and 12 s ofor that purpose we make use of the standard deviation

# %% [markdown]
# # Standard deviaiton
#
# ists an square rroot of the variance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# is we are asked where thus the 20 fallls with this standard deviationnwe can indicate that it fallls between 17 and 22
#
# to properly find out that onr element is how far away from anither weare needed to make use of  z score

# %% [markdown]
# # smaple varience --- use of (n-1)
# when we takethe sample data( greeen circle ) from og data (white circle ) the samole data needs to made an inference to an og data
#
#
#
#
#
# ---for now weare considering the "n" in place of N-1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. here blue dot or line indicate the the mean of whole data the greem areas are the sample data selected from the population data
# 2. supose we sel the four point with circle as an samle data and compute the mean of taht that smaple data
# 3. if we tried to compute the distance bet the mean of sample and population it is more or huge so we can cinclude that

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # random variables
# random variables is the function whose values is dirived from diff process

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# her x can be any value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. --- continous random variable ---> has no specific value its values changes continously
