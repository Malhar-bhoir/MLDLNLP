# %% [markdown]
# # measure of the central tendency
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Mean
#
# mean is sum of all the values divided by total number of the values

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 1. sample is an subset of the population
# 2. ---N ---- is the toatal anumber of the samples

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. ouliers arethe numbers that dos not belong to this dstribution

# %% [markdown]
# # median
# middlevalue in an dataset when the vlaue in dataset are arrange on the ascending or decending order

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. if the number of the elemtes are even then we take two of the central elements  ---- here it si 3,4
# 2. meadian is not effected by the outliers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Mode
# value that apppers most frequently in the dataset  --- can have one than more mode callled as the bimodal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # when to choose what
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. handling the missing value in tha ge colunn --- if data has symmmetrical dist ---usess mean to replace with the msiiing value
