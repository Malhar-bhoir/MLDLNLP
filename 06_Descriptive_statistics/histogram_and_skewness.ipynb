# %% [markdown]
# # histogram

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# bins are taken in 0-5 , 5-10 and so on as our bin sixe is = 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# frequency indicates the number of elemets that are present in the bin  or one grapg or range of ages
# 1. at 30 -35 we haave drawn the graph ffrom one frequency or at one element as we are loking forthe element that lies between the rnage ofthe given numbers

# %% [markdown]
# # skewness

# %% [markdown]
# 1. Skewness in probability theory and statistics is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.
# 2. no skewness means perferct in shape

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. relationship btw mean,meadian , mode --------- mean  = mediam  = mmode ... in symeetricla distributionin boxplot also as welll as in the box plot ... the 3 of them lies exacltly at the center

# %% [markdown]
# ## right Skewed
# --- right side of the curve is enllonged it is because ofthe out liers
# 1. in this --in boxplot the  meadium is not at taeh ceter its is shifter as sindicated by hte yellow line

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # left skeewd distributioonm

# %% [markdown]
# ![image.png](attachment:image.png)
