# %% [markdown]
# # covariance and core;lation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. det relation te two variable ---mostly in the continous variable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. to find this  relation below we makeuse fthe covariance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. as seen in data we can se that as the size increase proce increases
# 2. we can see the relation but we need t ofind the calue to determine the realtion .....covarience helps to quantifies the relation btw x and y

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # covarience
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. covarience does not have an infinit it ranges from - infinit y to a  + infifniuty
# 2. we cannnot say that cov(A,b) > or < cov(b,c)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # correaltion
#
# 1. ovvercome the problem of infinity that occur in covernce
# 2. if we divide the cov(x,y) with standard deviation of  x, y we can limit btw -1 and 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. peaarson rank coeeeis not able to capture the correlation for linear data
# 2.  for lineat iw lll provide cov as 1 wherre as for non lineaar the cov is 0 to 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. R(X) and R(Y )  ar simply the rank of the cariable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. spearman corr capturs the relation in nonlinae data or graph

# %% [markdown]
# ### real word scenarie
# uses of cov and cor in real world
#
# ![image.png](attachment:image.png)

# %% [markdown]
# here the number of the people staying in the house are not corelated ---- if we want we can remove this fature
