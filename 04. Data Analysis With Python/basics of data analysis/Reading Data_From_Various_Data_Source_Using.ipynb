# %%
import pandas as pd 
from io import StringIO
# data = '{"emp_name" : "ron" , "email" : "email@gmail.com " , "job" : "ML"}'
data = '{"emp_name" : ["ron" , "john" , "smith"] , "email" : ["ron@email" , "john@email" , "smith@email"] , "job" : ["ML" , "DL" , "NLP"]}'
df = pd.read_json(StringIO(data))

# %%
df
# Out:
#   emp_name        email  job
# 0      ron    ron@email   ML
# 1     john   john@email   DL
# 2    smith  smith@email  NLP

# %%
# converting the abouvrt datafram agoin into the json 
df.to_json() # by defualt it make use of the indexx 
# in output we can see that "0 : ron " ") " 0 : email "" etc
# Out:
# '{"emp_name":{"0":"ron","1":"john","2":"smith"},"email":{"0":"ron@email","1":"john@email","2":"smith@email"},"job":{"0":"ML","1":"DL","2":"NLP"}}'

# %%
df.to_json(orient = 'index')
# Out:
# '{"0":{"emp_name":"ron","email":"ron@email","job":"ML"},"1":{"emp_name":"john","email":"john@email","job":"DL"},"2":{"emp_name":"smith","email":"smith@email","job":"NLP"}}'

# %%
df.to_json(orient = 'records') # showsas the normal form
# Out:
# '[{"emp_name":"ron","email":"ron@email","job":"ML"},{"emp_name":"john","email":"john@email","job":"DL"},{"emp_name":"smith","email":"smith@email","job":"NLP"}]'

# %%
# how to read te dat from the url tha contain the dat in csv  foramt 
df = pd.read_csv("" , header  = None)

# %%
df
# Out:
#   emp_name        email  job
# 0      ron    ron@email   ML
# 1     john   john@email   DL
# 2    smith  smith@email  NLP

# %%
df.to_csv('wine.csv')
# using this is used to transfer the content ans aslo saved in the "CSV " file

# %%
# readingthe dat fro html file 
! pip install lxml
! pip installl html5lib
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: unknown command "installl" - maybe you meant "install"

# %%
url="https://www.fdic.gov/bank-failures/failed-bank-list"

df = pd.read_html(url)

# %%
df[0] # can be used to show the  table present on the html file
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
# "match" key word is usedto show the content ofthe table only witin thetable that contain that key word 
url= "https://en.wikipedia.org/wiki/Mobile_country_code"
df = pd.read_html(url, match ="country" , header = 0)[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # "match" key word is usedto show the content ofthe table only witin thetable that contain that key word
#       2 url= "https://en.wikipedia.org/wiki/Mobile_country_code"
# ----> 3 df = pd.read_html(url, match ="country" , header = 0)[0]
#
# File d:\MLDLNLP\myenv\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
# ...

# %%
! pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
dfexcel = pd.read_excel('data.xlsx')

# %%
# reading the pckle file
dfexcel.to_pickle('dfexcel')

# %%
# reading the pickle file 
pd.read_pickle('dfexcel')
# Out:
#    no.  Name
# 0    1   ron
# 1    2  john
# 2    3   mon
