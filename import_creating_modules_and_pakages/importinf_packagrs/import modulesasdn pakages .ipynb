# %% [markdown]
# # importing creating modulesa and pakages

# %%
import math 
math.sqrt(16) # use to perfrom the sqr root  operation
# Out:
# 4.0

# %%
# importing things or functuiin from the pakage
from math import sqrt, pi
sqrt(25)
pi
# Out:
# 3.141592653589793

# %%
# numpy usedt ocaary out he operation rellated to the aarrays\
import numpy as np

# %%
# creating an array 
import numpy as np 
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
#from math import * ----* here ^ helps us to inatall allthe avialbe modulesin the pakage

# %% [markdown]
# ## creation of o custom pakages

# %% [markdown]
# #### importing the customly created module insire the pakage created  usinf inint function of python

# %%
from package.maths import add
add(2,3) # this function is imported from the pakage created
# Out:
# 5

# %%
# or diff way of importing the pakage
from package import maths
maths.add(2,3)
# Out:
# 5

# %%
from package.maths import sub
sub(5,2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from package.maths import sub
#       2 sub(5,2)
#
# ImportError: cannot import name 'sub' from 'package.maths' (d:\MLDLNLP\import creating modules an d pakages\package\maths.py)

# %%
## creatiin of subpakages
